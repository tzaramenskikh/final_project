# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('people.csv')
data.head()
# Out:
#       id      bdate    city  sex deactivated first_name  last_name  \
# 0   6892  11.7.2003  Москва    1      banned        Аня   Лазарева
# 1   8684  17.9.1987  Москва    2         NaN     Андрей   Питушкин
# 2  13312        NaN     NaN    1      banned       Кира  Щербакова
# 3  14948       14.6   Praha    2         NaN   Владимир     Пырлик
# 4  17574  28.2.1986  Москва    1      banned       Майя  Смолицкая
#
#    can_access_closed  is_closed home_town           group
# 0               True      False       NaN  Хочу в НИУ ВШЭ
# 1               True      False       NaN  Хочу в НИУ ВШЭ
# 2               True      False       NaN  Хочу в НИУ ВШЭ
# 3               True      False       NaN  Хочу в НИУ ВШЭ
# 4               True      False       NaN  Хочу в НИУ ВШЭ

# %%
data['sex'] = np.where(data['sex']==1, 'Female', 'Male')
data.head()
# Out:
#       id      bdate    city     sex deactivated first_name  last_name  \
# 0   6892  11.7.2003  Москва  Female      banned        Аня   Лазарева
# 1   8684  17.9.1987  Москва    Male         NaN     Андрей   Питушкин
# 2  13312        NaN     NaN  Female      banned       Кира  Щербакова
# 3  14948       14.6   Praha    Male         NaN   Владимир     Пырлик
# 4  17574  28.2.1986  Москва  Female      banned       Майя  Смолицкая
#
#    can_access_closed  is_closed home_town           group
# 0               True      False       NaN  Хочу в НИУ ВШЭ
# 1               True      False       NaN  Хочу в НИУ ВШЭ
# 2               True      False       NaN  Хочу в НИУ ВШЭ
# 3               True      False       NaN  Хочу в НИУ ВШЭ
# 4               True      False       NaN  Хочу в НИУ ВШЭ

# %%
df_bdate = data

# %%
df_ = df_bdate['bdate'].str.split('.', expand=True)

# %%
df_bdate = pd.concat([df_bdate, df_], axis=1)

# %%
df_bdate
# Out:
#               id       bdate    city     sex deactivated first_name  \
# 0           6892   11.7.2003  Москва  Female      banned        Аня
# 1           8684   17.9.1987  Москва    Male         NaN     Андрей
# 2          13312         NaN     NaN  Female      banned       Кира
# 3          14948        14.6   Praha    Male         NaN   Владимир
# 4          17574   28.2.1986  Москва  Female      banned       Майя
# ...          ...         ...     ...     ...         ...        ...
# 33780  814013443   25.8.2004  Москва  Female         NaN     Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN      Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN       Маня
# 33783  830579149  19.10.1994     NaN  Female         NaN        Юна
# 33784  847411067   26.7.1988     NaN  Female         NaN       Юлия
#
#           last_name  can_access_closed  is_closed home_town  \
# 0          Лазарева               True      False       NaN
# ...

# %%
df_bdate = df_bdate.rename(columns={0: 'day_bdate', 1: 'month_bdate', 2: 'year_bdate'})
df_bdate = df_bdate.drop(['day_bdate', 'month_bdate'], axis=1)
df_bdate
# Out:
#               id       bdate    city     sex deactivated first_name  \
# 0           6892   11.7.2003  Москва  Female      banned        Аня
# 1           8684   17.9.1987  Москва    Male         NaN     Андрей
# 2          13312         NaN     NaN  Female      banned       Кира
# 3          14948        14.6   Praha    Male         NaN   Владимир
# 4          17574   28.2.1986  Москва  Female      banned       Майя
# ...          ...         ...     ...     ...         ...        ...
# 33780  814013443   25.8.2004  Москва  Female         NaN     Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN      Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN       Маня
# 33783  830579149  19.10.1994     NaN  Female         NaN        Юна
# 33784  847411067   26.7.1988     NaN  Female         NaN       Юлия
#
#           last_name  can_access_closed  is_closed home_town  \
# 0          Лазарева               True      False       NaN
# ...

# %%
df_bdate.isnull().sum()
# Out:
# id                       0
# bdate                 6459
# city                 11889
# sex                      0
# deactivated          29609
# first_name               0
# last_name             1749
# can_access_closed        0
# is_closed                0
# home_town            28056
# group                    0
# year_bdate           20815
# dtype: int64

# %%
df_bdate = df_bdate.dropna(subset=['year_bdate'])
df_bdate
# Out:
#               id       bdate    city     sex deactivated  first_name  \
# 0           6892   11.7.2003  Москва  Female      banned         Аня
# 1           8684   17.9.1987  Москва    Male         NaN      Андрей
# 4          17574   28.2.1986  Москва  Female      banned        Майя
# 13         65995    6.2.1984  Москва    Male         NaN        Пётр
# 15         81206   18.9.1988  Москва    Male         NaN  Константин
# ...          ...         ...     ...     ...         ...         ...
# 33780  814013443   25.8.2004  Москва  Female         NaN      Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN       Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN        Маня
# 33783  830579149  19.10.1994     NaN  Female         NaN         Юна
# 33784  847411067   26.7.1988     NaN  Female         NaN        Юлия
#
#            last_name  can_access_closed  is_closed home_town  \
# 0           Лазарева               True      False       NaN
# ...

# %%
df_bdate.dtypes
# Out:
# id                    int64
# bdate                object
# city                 object
# sex                  object
# deactivated          object
# first_name           object
# last_name            object
# can_access_closed      bool
# is_closed              bool
# home_town            object
# group                object
# year_bdate           object
# dtype: object

# %%
df_bdate['year_bdate'] = pd.to_numeric(df_bdate['year_bdate'], errors= 'coerce')

# %%
df_bdate['age'] = 2024 - df_bdate['year_bdate']

# %%
df_bdate
# Out:
#               id       bdate    city     sex deactivated  first_name  \
# 0           6892   11.7.2003  Москва  Female      banned         Аня
# 1           8684   17.9.1987  Москва    Male         NaN      Андрей
# 4          17574   28.2.1986  Москва  Female      banned        Майя
# 13         65995    6.2.1984  Москва    Male         NaN        Пётр
# 15         81206   18.9.1988  Москва    Male         NaN  Константин
# ...          ...         ...     ...     ...         ...         ...
# 33780  814013443   25.8.2004  Москва  Female         NaN      Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN       Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN        Маня
# 33783  830579149  19.10.1994     NaN  Female         NaN         Юна
# 33784  847411067   26.7.1988     NaN  Female         NaN        Юлия
#
#            last_name  can_access_closed  is_closed home_town  \
# 0           Лазарева               True      False       NaN
# ...

# %%
df_bdate_1=data

# %%
df_1 = df_bdate_1['bdate'].str.split('.', expand=True)

# %%
df_bdate_1 = pd.concat([df_bdate_1, df_1], axis=1)

# %%
df_bdate_1
# Out:
#               id       bdate    city     sex deactivated first_name  \
# 0           6892   11.7.2003  Москва  Female      banned        Аня
# 1           8684   17.9.1987  Москва    Male         NaN     Андрей
# 2          13312         NaN     NaN  Female      banned       Кира
# 3          14948        14.6   Praha    Male         NaN   Владимир
# 4          17574   28.2.1986  Москва  Female      banned       Майя
# ...          ...         ...     ...     ...         ...        ...
# 33780  814013443   25.8.2004  Москва  Female         NaN     Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN      Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN       Маня
# 33783  830579149  19.10.1994     NaN  Female         NaN        Юна
# 33784  847411067   26.7.1988     NaN  Female         NaN       Юлия
#
#           last_name  can_access_closed  is_closed home_town  \
# 0          Лазарева               True      False       NaN
# ...

# %%
df_bdate_1 = df_bdate_1.rename(columns={0: 'day_bdate', 1: 'month_bdate', 2: 'year_bdate'})
df_bdate_1 = df_bdate_1.drop(['day_bdate', 'month_bdate'], axis=1)
df_bdate_1
# Out:
#               id       bdate    city     sex deactivated first_name  \
# 0           6892   11.7.2003  Москва  Female      banned        Аня
# 1           8684   17.9.1987  Москва    Male         NaN     Андрей
# 2          13312         NaN     NaN  Female      banned       Кира
# 3          14948        14.6   Praha    Male         NaN   Владимир
# 4          17574   28.2.1986  Москва  Female      banned       Майя
# ...          ...         ...     ...     ...         ...        ...
# 33780  814013443   25.8.2004  Москва  Female         NaN     Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN      Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN       Маня
# 33783  830579149  19.10.1994     NaN  Female         NaN        Юна
# 33784  847411067   26.7.1988     NaN  Female         NaN       Юлия
#
#           last_name  can_access_closed  is_closed home_town  \
# 0          Лазарева               True      False       NaN
# ...

# %%
df_bdate_1.dtypes
# Out:
# id                    int64
# bdate                object
# city                 object
# sex                  object
# deactivated          object
# first_name           object
# last_name            object
# can_access_closed      bool
# is_closed              bool
# home_town            object
# group                object
# year_bdate           object
# dtype: object

# %%
df_bdate_1['year_bdate'] = pd.to_numeric(df_bdate_1['year_bdate'], errors= 'coerce')

# %%
missing_mask = df_bdate_1['year_bdate'].isnull()

median_value = df_bdate_1['year_bdate'].median()
mean_value = df_bdate_1['year_bdate'].mean()

for index, row in df_bdate_1.iterrows():
    if pd.isnull(row['year_bdate']):
        replacement_value = np.random.choice([median_value, mean_value])
        df_bdate_1.at[index, 'year_bdate'] = replacement_value

# %%
df_bdate_1
# Out:
#               id       bdate    city     sex deactivated first_name  \
# 0           6892   11.7.2003  Москва  Female      banned        Аня
# 1           8684   17.9.1987  Москва    Male         NaN     Андрей
# 2          13312         NaN     NaN  Female      banned       Кира
# 3          14948        14.6   Praha    Male         NaN   Владимир
# 4          17574   28.2.1986  Москва  Female      banned       Майя
# ...          ...         ...     ...     ...         ...        ...
# 33780  814013443   25.8.2004  Москва  Female         NaN     Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN      Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN       Маня
# 33783  830579149  19.10.1994     NaN  Female         NaN        Юна
# 33784  847411067   26.7.1988     NaN  Female         NaN       Юлия
#
#           last_name  can_access_closed  is_closed home_town  \
# 0          Лазарева               True      False       NaN
# ...

# %%
df_bdate_1['year_bdate'] = df_bdate_1['year_bdate'].astype(int)
df_bdate_1
# Out:
#               id       bdate    city     sex deactivated first_name  \
# 0           6892   11.7.2003  Москва  Female      banned        Аня
# 1           8684   17.9.1987  Москва    Male         NaN     Андрей
# 2          13312         NaN     NaN  Female      banned       Кира
# 3          14948        14.6   Praha    Male         NaN   Владимир
# 4          17574   28.2.1986  Москва  Female      banned       Майя
# ...          ...         ...     ...     ...         ...        ...
# 33780  814013443   25.8.2004  Москва  Female         NaN     Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN      Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN       Маня
# 33783  830579149  19.10.1994     NaN  Female         NaN        Юна
# 33784  847411067   26.7.1988     NaN  Female         NaN       Юлия
#
#           last_name  can_access_closed  is_closed home_town  \
# 0          Лазарева               True      False       NaN
# ...

# %%
df_bdate_1['age'] = 2024 - df_bdate_1['year_bdate']

# %%
df_bdate_1
# Out:
#               id       bdate    city     sex deactivated first_name  \
# 0           6892   11.7.2003  Москва  Female      banned        Аня
# 1           8684   17.9.1987  Москва    Male         NaN     Андрей
# 2          13312         NaN     NaN  Female      banned       Кира
# 3          14948        14.6   Praha    Male         NaN   Владимир
# 4          17574   28.2.1986  Москва  Female      banned       Майя
# ...          ...         ...     ...     ...         ...        ...
# 33780  814013443   25.8.2004  Москва  Female         NaN     Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN      Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN       Маня
# 33783  830579149  19.10.1994     NaN  Female         NaN        Юна
# 33784  847411067   26.7.1988     NaN  Female         NaN       Юлия
#
#           last_name  can_access_closed  is_closed home_town  \
# 0          Лазарева               True      False       NaN
# ...

# %%
df=df_bdate_1

# %%
city_counts = df['city'].value_counts()
unique_cities = city_counts.index.tolist()
print(unique_cities)
# Out:
# ['Москва', 'Санкт-Петербург', 'Нижний Новгород', 'Пермь', 'Екатеринбург', 'Казань', 'Самара', 'Воронеж', 'Новосибирск', 'Уфа', 'Челябинск', 'Ростов-на-Дону', 'Краснодар', 'Красноярск', 'Волгоград', 'Минск', 'Ижевск', 'Киев', 'Ярославль', 'Киров', 'Тюмень', 'Калининград', 'Омск', 'Саратов', 'Вологда', 'Пенза', 'Рязань', 'Чебоксары', 'Тольятти', 'Липецк', 'Владивосток', 'Белгород', 'Иркутск', 'Тверь', 'Тула', 'Севастополь', 'Череповец', 'Владимир', 'Иваново', 'Набережные Челны', 'Тамбов', 'Оренбург', 'Ульяновск', 'Ставрополь', 'New York City', 'Смоленск', 'Курск', 'Мурманск', 'Барнаул', 'Сочи', 'Харьков', 'Томск', 'Алматы', 'Донецк', 'Королёв', 'Ташкент', 'Орёл', 'Подольск', 'Кемерово', 'Астрахань', 'Балашиха', 'Калуга', 'Днепр (Днепропетровск)', 'Los Angeles', 'Архангельск', 'Хабаровск', 'Сыктывкар', 'Улан-Удэ', 'Саранск', 'Брянск', 'Бишкек', 'Симферополь', 'Мытищи', 'Одесса', 'Псков', 'Магнитогорск', 'Великий Новгород', 'Петрозаводск', 'Кострома', 'Йошкар-Ола', 'Новороссийск', 'Запор
# ...

# %%
df.to_csv('people_1.csv', index=False)

# %%
df_1 = pd.read_csv('people_2.csv')
df_1.head()
# Out:
#           id       bdate       city     sex deactivated first_name  \
# 0   52716126  21.11.1992  Ульяновск    Male         NaN     Микмик
# 1  219224357    5.9.2001     Москва  Female         NaN        Аня
# 2  444017526  19.12.2005     Абакан    Male         NaN    Алексей
# 3  444017526  19.12.2005     Абакан    Male         NaN    Алексей
# 4  159039847        13.9      Томск  Female         NaN        Аня
#
#     last_name  can_access_closed  is_closed home_town  \
# 0      Форэва               True      False       NaN
# 1  Григорьева               True      False      Абай
# 2  Гончаренко               True      False    Абакан
# 3  Гончаренко               True      False    Абакан
# 4    Жвирблис               True      False    Абакан
#
#                            group  year_bdate  age
# 0                 Хочу в НИУ ВШЭ        1992   32
# 1          Хочу в Институт медиа        2001   23
# 2                 Хочу в НИУ ВШЭ        2005   19
# ...

# %%
df_1 = df_1.drop(['can_access_closed', 'is_closed', 'bdate'], axis=1)
df_1
# Out:
#               id       city     sex deactivated first_name   last_name  \
# 0       52716126  Ульяновск    Male         NaN     Микмик      Форэва
# 1      219224357     Москва  Female         NaN        Аня  Григорьева
# 2      444017526     Абакан    Male         NaN    Алексей  Гончаренко
# 3      444017526     Абакан    Male         NaN    Алексей  Гончаренко
# 4      159039847      Томск  Female         NaN        Аня    Жвирблис
# ...          ...        ...     ...         ...        ...         ...
# 33780  806055374        NaN  Female         NaN    Аделина        Камю
# 33781  809298445        NaN  Female         NaN        Зоя      Шурова
# 33782  816147572        NaN  Female         NaN      Софья    Романова
# 33783  830185740        NaN  Female         NaN       Маня        Блин
# 33784  847411067        NaN  Female         NaN       Юлия  Капитанова
#
#       home_town                          group  year_bdate  age
# ...

# %%
duplicate_rows = df_1[df_1.duplicated(subset=['id'], keep=False)]
duplicate_rows
# Out:
#               id     city     sex deactivated first_name     last_name  \
# 2      444017526   Абакан    Male         NaN    Алексей    Гончаренко
# 3      444017526   Абакан    Male         NaN    Алексей    Гончаренко
# 63     520111060  Ангарск  Female         NaN       Саша      Солнцева
# 64     520111060  Ангарск  Female         NaN       Саша      Солнцева
# 84     331801731  Армавир  Female         NaN      Мария      Андреева
# ...          ...      ...     ...         ...        ...           ...
# 33758  717397045      NaN  Female         NaN     Сергей    Головцинов
# 33761  722322268      NaN  Female         NaN       Юлия     Дубайская
# 33763  738102147      NaN  Female         NaN        Аня      Шеляпина
# 33765  740413931      NaN  Female         NaN       Vera  Alexandrovna
# 33766  746996479      NaN  Female         NaN    Варвара      Романова
#
#       home_town                          group  year_bdate  age
# ...

# %%
duplicate_rows_with_condition = df_1[df_1.duplicated(subset=['id'], keep=False) & (df_1['group'] == 'Хочу на факультет права Вышки')]
duplicate_rows_with_condition
# Out:
#               id     city     sex deactivated first_name     last_name  \
# 3      444017526   Абакан    Male         NaN    Алексей    Гончаренко
# 64     520111060  Ангарск  Female         NaN       Саша      Солнцева
# 87     331801731  Армавир  Female         NaN      Мария      Андреева
# 94     386174575      NaN  Female         NaN  Екатерина    Веснинцева
# 95     556066631      NaN  Female         NaN    Розалия      Хачатрян
# ...          ...      ...     ...         ...        ...           ...
# 33758  717397045      NaN  Female         NaN     Сергей    Головцинов
# 33761  722322268      NaN  Female         NaN       Юлия     Дубайская
# 33763  738102147      NaN  Female         NaN        Аня      Шеляпина
# 33765  740413931      NaN  Female         NaN       Vera  Alexandrovna
# 33766  746996479      NaN  Female         NaN    Варвара      Романова
#
#       home_town                          group  year_bdate  age
# ...

# %%
duplicate_rows_with_condition_2 = df_1[df_1.duplicated(subset=['id'], keep=False) & (df_1['group'] == 'Хочу в Институт медиа')]
duplicate_rows_with_condition_2
# Out:
#               id    city     sex deactivated  first_name  last_name  \
# 290    291621255  Москва    Male         NaN        Олег    Данилов
# 325    572641830  Москва  Female         NaN   Екатерина    Бычкова
# 396     44484428  Москва  Female         NaN        Лиза     Шанова
# 418    498638896     NaN  Female         NaN         Ира   Конышева
# 421    166308012  Москва  Female         NaN         Аня   Могутова
# ...          ...     ...     ...         ...         ...        ...
# 33247  710877159     NaN  Female         NaN        Соня    Кулиныч
# 33253  742738946     NaN  Female         NaN        Соня   Булыкина
# 33259  761424726     NaN  Female         NaN  Александра  Казанцева
# 33260  776545415     NaN  Female         NaN       Ирина   Назарова
# 33266  816396835     NaN  Female         NaN      Нурона     Шехова
#
#               home_town                  group  year_bdate  age
# 290               Бийск  Хочу в Институт медиа        2001   23
# ...

# %%
df_clean = df_1.drop_duplicates(subset=['id'], keep='first')
df_clean
# Out:
#               id       city     sex deactivated first_name   last_name  \
# 0       52716126  Ульяновск    Male         NaN     Микмик      Форэва
# 1      219224357     Москва  Female         NaN        Аня  Григорьева
# 2      444017526     Абакан    Male         NaN    Алексей  Гончаренко
# 4      159039847      Томск  Female         NaN        Аня    Жвирблис
# 5      390896196        NaN  Female         NaN       Поля     Шевцова
# ...          ...        ...     ...         ...        ...         ...
# 33780  806055374        NaN  Female         NaN    Аделина        Камю
# 33781  809298445        NaN  Female         NaN        Зоя      Шурова
# 33782  816147572        NaN  Female         NaN      Софья    Романова
# 33783  830185740        NaN  Female         NaN       Маня        Блин
# 33784  847411067        NaN  Female         NaN       Юлия  Капитанова
#
#       home_town                          group  year_bdate  age
# ...

# %%
df_bdate=df_bdate.drop_duplicates(subset=['id'], keep='first')
df_bdate
# Out:
#               id       bdate    city     sex deactivated  first_name  \
# 0           6892   11.7.2003  Москва  Female      banned         Аня
# 1           8684   17.9.1987  Москва    Male         NaN      Андрей
# 4          17574   28.2.1986  Москва  Female      banned        Майя
# 13         65995    6.2.1984  Москва    Male         NaN        Пётр
# 15         81206   18.9.1988  Москва    Male         NaN  Константин
# ...          ...         ...     ...     ...         ...         ...
# 33779  809298445  27.11.1968     NaN  Female         NaN         Зоя
# 33780  814013443   25.8.2004  Москва  Female         NaN      Мадина
# 33781  816147572    3.2.2000     NaN  Female         NaN       Софья
# 33782  830185740    8.8.2006     NaN  Female         NaN        Маня
# 33784  847411067   26.7.1988     NaN  Female         NaN        Юлия
#
#            last_name  can_access_closed  is_closed home_town  \
# 0           Лазарева               True      False       NaN
# ...

# %%
mean_age = df_clean['age'].mean()
print("Средний возраст:", mean_age)
median_age = df_clean['age'].median()
print("Медианный возраст:", median_age)
mode_age = df_clean['age'].mode()
print("Значение моды:", mode_age)
# Out:
# Средний возраст: 28.03718845583114
# Медианный возраст: 24.0
# Значение моды: 0    24
# Name: age, dtype: int64

# %%
mean_age_1 = df_bdate['age'].mean()
print("Средний возраст:", mean_age)
median_age_1 = df_bdate['age'].median()
print("Медианный возраст:", median_age)
mode_age_1 = df_bdate['age'].mode()
print("Значение моды:", mode_age)
# Out:
# Средний возраст: 28.03718845583114
# Медианный возраст: 24.0
# Значение моды: 0    24
# Name: age, dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df_clean['age'], vert=False)
plt.title('Ящик с усами для возраста')
plt.xlabel('Возраст')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df_bdate['age'], vert=False)
plt.title('Ящик с усами для возраста')
plt.xlabel('Возраст')
plt.show()

# %%
Q1 = df_clean['age'].quantile(0.25)
Q3 = df_clean['age'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_clean = df_clean[(df_clean['age'] >= lower_bound) & (df_clean['age'] <= upper_bound)]

# %%
mean_age_2 = df_clean['age'].mean()
print("Средний возраст:", mean_age)
median_age_2 = df_clean['age'].median()
print("Медианный возраст:", median_age)
mode_age_2 = df_clean['age'].mode()
print("Значение моды:", mode_age)
# Out:
# Средний возраст: 28.03718845583114
# Медианный возраст: 24.0
# Значение моды: 0    24
# Name: age, dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df_clean['age'], vert=False)
plt.title('Ящик с усами для возраста')
plt.xlabel('Возраст')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_clean['age'], bins=30, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
df_clean
# Out:
#               id       city     sex deactivated first_name   last_name  \
# 0       52716126  Ульяновск    Male         NaN     Микмик      Форэва
# 1      219224357     Москва  Female         NaN        Аня  Григорьева
# 2      444017526     Абакан    Male         NaN    Алексей  Гончаренко
# 4      159039847      Томск  Female         NaN        Аня    Жвирблис
# 5      390896196        NaN  Female         NaN       Поля     Шевцова
# ...          ...        ...     ...         ...        ...         ...
# 33779  803587569        NaN  Female         NaN    Наталья    Науменко
# 33780  806055374        NaN  Female         NaN    Аделина        Камю
# 33782  816147572        NaN  Female         NaN      Софья    Романова
# 33783  830185740        NaN  Female         NaN       Маня        Блин
# 33784  847411067        NaN  Female         NaN       Юлия  Капитанова
#
#       home_town                          group  year_bdate  age
# ...

# %%
sex_counts = df_clean['sex'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(sex_counts, labels=sex_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Gender Distribution')
plt.axis('equal') 
plt.show()

# %%
df_clean['deactivated'].fillna('Unknown', inplace=True)

deactivated_counts = df_clean['deactivated'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(deactivated_counts, labels=deactivated_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Deactivated Accounts Distribution')
plt.axis('equal')
plt.show()
# Out:
# /var/folders/44/k10r3brn4v9g1my31l1xqgx40000gn/T/ipykernel_69544/606709357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['deactivated'].fillna('Unknown', inplace=True)

# %%
df_clean.groupby(
    by=['city'])[['id']].count().sort_values(by='id', ascending=False).head(20)
# Out:
#                    id
# city
# Москва           9289
# Санкт-Петербург  1543
# Нижний Новгород   351
# Пермь             249
# Екатеринбург      233
# Казань            227
# Самара            161
# Воронеж           155
# Новосибирск       154
# Уфа               148
# Челябинск         140
# Ростов-на-Дону    129
# Краснодар         125
# Минск             108
# Красноярск        106
# Волгоград          98
# Киев               92
# Калининград        85
# Ярославль          84
# Ижевск             84

# %%
df_clean.groupby(
    by=['home_town'])[['id']].count().sort_values(by='id', ascending=False).head(20)
# Out:
#                     id
# home_town
# Москва            1373
# Санкт-Петеррбург   228
# Нижний Новгород    102
# Екатеринбург        71
# Пермь               68
# Казань              58
# Самара              58
# Воронеж             55
# Новосибирск         55
# Ростов-На-Дону      52
# Челябинск           50
# Киров               50
# Краснодар           45
# Красноярск          44
# Ижевск              43
# Омск                42
# Тольятти            39
# Уфа                 39
# Иркутск             36
# Владивосток         35

# %%
matching_cities = (df_clean['city'] == df_clean['home_town']).sum()

print("Количество людей, у которых, место рождения и место проживания совпадают:", matching_cities)
# Out:
# Количество людей, у которых, место рождения и место проживания совпадают: 2319

# %%
df_clean['city'].nunique()
# Out:
# 1370

# %%
df_clean['home_town'].nunique()
# Out:
# 862

# %%
plt.figure(figsize=(6, 6))
df_clean['group'].value_counts().plot(kind='bar', color='orange')
plt.title('Distribution by Group')
plt.xlabel('Group')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(6, 6))
sns.boxplot(x='sex', y='age', data=df_clean)
plt.title('Age Distribution by Gender')
plt.show()

# %%
pivot_table_group_age = pd.pivot_table(df_clean, index='group', values='age', aggfunc=['mean', 'median', 'std', 'count'])
pivot_table_group_age
# Out:
#                                     mean median       std  count
#                                      age    age       age    age
# group
# Хочу в Институт медиа          24.850141     24  3.926107   1061
# Хочу в НИУ ВШЭ                 25.842896     24  4.259687  28949
# Хочу на факультет права Вышки  24.667418     24  4.645793    887

# %%
pivot_table_group_sex = pd.pivot_table(df_clean, index='group', columns='sex', aggfunc='size', fill_value=0)
pivot_table_group_sex
# Out:
# sex                            Female  Male
# group
# Хочу в Институт медиа             914   147
# Хочу в НИУ ВШЭ                  19361  9588
# Хочу на факультет права Вышки     637   250

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

X = df_clean[['age', 'city', 'sex', 'group']] 
X_encoded = pd.get_dummies(X) 
scaler = StandardScaler()  
X_scaled = scaler.fit_transform(X_encoded) 

inertia = []
for n_clusters in range(1, 11):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)
cluster_labels = kmeans.labels_

df_clean['cluster'] = cluster_labels

cluster_counts = df_clean['cluster'].value_counts()
print("Counts per cluster:")
print(cluster_counts)
# Out:
# Counts per cluster:
# 0    30885
# 2       10
# 1        2
# Name: cluster, dtype: int64
# /var/folders/44/k10r3brn4v9g1my31l1xqgx40000gn/T/ipykernel_69544/1461067799.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['cluster'] = cluster_labels

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

X = df_clean[['age', 'city', 'sex']] 
X_encoded = pd.get_dummies(X)
y = df_clean['group']

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

print(classification_report(y_test, y_pred))
# Out:
# /Users/tzaramenskikh/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/tzaramenskikh/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.9407766990291262
#                                precision    recall  f1-score   support
#
# ...
